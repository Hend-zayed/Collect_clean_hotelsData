# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
import pandas as pd
df = pd.read_excel('hotel.xlsx', sheet_name= 'data')
print(df)
df.info()
# Out:
#                 location                                      business name  \
# 0             Lancashire                        Hampton by Hilton Blackburn
# 1             Lancashire                              Holiday Inn Lancaster
# 2             Lancashire                             Preston Marriott Hotel
# 3             Lancashire                       Crow Wood Hotel & Spa Resort
# 4             Lancashire                                        The Midland
# ...                  ...                                                ...
# 1188  Greater Manchester                               Premier Inn Rochdale
# 1189  Greater Manchester                  Premier Inn Stockport South hotel
# 1190  Greater Manchester          Premier Inn Wigan North (M6 Jct 27) hotel
# 1191  Greater Manchester  Premier Inn Manchester Airport M56 J6 Runger L...
# 1192  Greater Manchester                                           pendulum
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2 entries, 1 to 2
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   location       2 non-null      object
#  1   business name  2 non-null      object
#  2   Star Rating    2 non-null      float64
#  3   address1       2 non-null      object
#  4   address2       2 non-null      object
#  5   Town County    2 non-null      object
#  6   Zipcode        2 non-null      object
#  7   Phone          2 non-null      object
#  8   source link    2 non-null      object
# dtypes: float64(1), object(8)
# memory usage: 160.0+ bytes

# %%
a = len(df['source link'])

# %%
i = 0
for i in range(a):
    url = df['source link'][i]
    print (url)
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    info= soup.find_all('div', {'class': 'GtAk2e'})
    hotel_data = []
    for a in info:
        streetAddress= a.find('span', {'class': 'XGa8fd'}).text
        hotel_data.append(streetAddress)
#     print(hotel_data[0])
#     print(hotel_data[1])
#     df['address1'][i] = hotel_data[0]
#     df['Phone'][i] = hotel_data[1]
    try:
        print(hotel_data[0])
        print(hotel_data[1])
        df['address1'][i] = hotel_data[0]
        df['Phone'][i] = hotel_data[1]
    except IndexError:
        print(streetAddress)
        df['address1'][i] = streetAddress
    pass
# Out:
# https://www.google.com/travel/hotels/Lancashire/entity/CgsIosmk5svki6_jARABGnxBR1pJRWdha0xqdlI0OXNLV2Vrc3c3bFdwdTY1LTZZUTVRNjgtVExQVzRCUU5JdUZSOTJMcWdRX09YVVRsVnZsQkROb1FhLWptTmpCeUFXVmlabEczekRqR2hLcTdsei1DWHRYMDZLNVdiWjdvT0tTdkJVZ2c0X2NpS3RC?g2lb=2502548%2C2503781%2C4258168%2C4270442%2C4306835%2C4317915%2C4328159%2C4371335%2C4401769%2C4419364%2C4463666%2C4466981%2C4482194%2C4482438%2C4486153%2C4491350%2C4495816%2C4496891%2C4503421%2C4507899%2C4270859%2C4284970%2C4291517&hl=en-BD&gl=bd&ap=MABoAA&rp=OAFAAEgC&ictx=1&sa=X&utm_campaign=sharing&utm_medium=link&utm_source=htls&ts=CAESABpVCjcSMzIlMHg0ODdhNGQ0YzUyMjZmNWRiOjB4YjU0OTdkZDEwYzQ2MWI2NToKTGFuY2FzaGlyZRoAEhoSFAoHCOUPEAMYCRIHCOUPEAMYChgBMgIIAioPCgsoAUoCIAE6A0JEVBoA&ved=2ahUKEwiP7Zm61_juAhUbi2YCHWRHAigQyvcEegUIARCyAQ
# 2 Frontier Ave, Blackburn BB1 3AL, United Kingdom
# +44 1254 946060
# ...

# %%
i = 0
for i in range(a):
    url = df['source link'][i]
    print (url)
    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    info= soup.find_all('div', {'class': 'GtAk2e'})
    hotel_data = []
    for a in info:
        streetAddress= a.find('span', {'class': 'XGa8fd'})
        hotel_data.append(streetAddress)
    print (hotel_data)
    print(hotel_data[0])
    print(hotel_data[1])
#     df['address1'][i] = hotel_data[0]
#     df['Phone'][i] = hotel_data[1]
#     try:
#         print(hotel_data[0])
#         print(hotel_data[1])
#         df['address1'][i] = hotel_data[0]
#         df['Phone'][i] = hotel_data[1]
#     except IndexError:
#         print(streetAddress)
#         df['address1'][i] = streetAddress
#     pass
# Out:
# https://www.google.com/travel/hotels/Lancashire/entity/CgsIosmk5svki6_jARABGnxBR1pJRWdha0xqdlI0OXNLV2Vrc3c3bFdwdTY1LTZZUTVRNjgtVExQVzRCUU5JdUZSOTJMcWdRX09YVVRsVnZsQkROb1FhLWptTmpCeUFXVmlabEczekRqR2hLcTdsei1DWHRYMDZLNVdiWjdvT0tTdkJVZ2c0X2NpS3RC?g2lb=2502548%2C2503781%2C4258168%2C4270442%2C4306835%2C4317915%2C4328159%2C4371335%2C4401769%2C4419364%2C4463666%2C4466981%2C4482194%2C4482438%2C4486153%2C4491350%2C4495816%2C4496891%2C4503421%2C4507899%2C4270859%2C4284970%2C4291517&hl=en-BD&gl=bd&ap=MABoAA&rp=OAFAAEgC&ictx=1&sa=X&utm_campaign=sharing&utm_medium=link&utm_source=htls&ts=CAESABpVCjcSMzIlMHg0ODdhNGQ0YzUyMjZmNWRiOjB4YjU0OTdkZDEwYzQ2MWI2NToKTGFuY2FzaGlyZRoAEhoSFAoHCOUPEAMYCRIHCOUPEAMYChgBMgIIAioPCgsoAUoCIAE6A0JEVBoA&ved=2ahUKEwiP7Zm61_juAhUbi2YCHWRHAigQyvcEegUIARCyAQ
# ...

# %%
df.head(20)
# Out:
#       location                              business name  Star Rating  \
# 0   Lancashire                Hampton by Hilton Blackburn          4.7
# 1   Lancashire                      Holiday Inn Lancaster          3.9
# 2   Lancashire                     Preston Marriott Hotel          4.1
# 3   Lancashire               Crow Wood Hotel & Spa Resort          4.8
# 4   Lancashire                                The Midland          4.5
# 5   Lancashire  Mercure Blackburn Dunkenhalgh Hotel & Spa          4.1
# 6   Lancashire                Hampton by Hilton Blackburn          4.7
# 7   Lancashire                   Hotel ibis Preston North          4.0
# 8   Lancashire                      Holiday Inn Lancaster          3.9
# 9   Lancashire              Macdonald Tickled Trout Hotel          4.0
# 10  Lancashire                        Holiday Inn Preston          3.9
# 11  Lancashire                         Barton Manor Hotel          4.4
# ...

# %%
with pd.ExcelWriter('hote_hendn.xlsx') as writer:
    df.to_excel(writer, sheet_name='Sheet1')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   location       1193 non-null   object
#  1   business name  1193 non-null   object
#  2   Star Rating    1164 non-null   float64
#  3   address1       211 non-null    object
#  4   address2       2 non-null      object
#  5   Town County    3 non-null      object
#  6   Zipcode        3 non-null      object
#  7   Phone          194 non-null    object
#  8   source link    1193 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 84.3+ KB

# %%
df.tail(20)
# Out:
#                 location                                      business name  \
# 1177  Greater Manchester      Premier Inn Manchester City Centre West hotel
# 1178  Greater Manchester                                      Mercury Motel
# 1179  Greater Manchester       Premier Inn Manchester (Salford Quays) hotel
# 1180  Greater Manchester  Premier Inn Manchester City Centre (Deansgate ...
# 1181  Greater Manchester             Premier Inn Manchester (Cheadle) hotel
# 1182  Greater Manchester  Premier Inn Manchester City Centre (Deansgate ...
# 1183  Greater Manchester                  Premier Inn Wigan (M6, J25) hotel
# 1184  Greater Manchester         Premier Inn Manchester West Didsbury hotel
# 1185  Greater Manchester                Premier Inn Stockport Central hotel
# 1186  Greater Manchester  Premier Inn Manchester City Centre (Portland S...
# 1187  Greater Manchester      Premier Inn Manchester City Centre West hotel
# ...
