# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
df = pd.read_excel('hote_hendn.xlsx')
print(df)
df.info()
# Out:
#       Unnamed: 0            location  \
# 0              0          Lancashire
# 1              1          Lancashire
# 2              2          Lancashire
# 3              3          Lancashire
# 4              4          Lancashire
# ...          ...                 ...
# 1188        1188  Greater Manchester
# 1189        1189  Greater Manchester
# 1190        1190  Greater Manchester
# 1191        1191  Greater Manchester
# 1192        1192  Greater Manchester
#
#                                           business name  Star Rating  \
# 0                           Hampton by Hilton Blackburn          4.7
# 1                                 Holiday Inn Lancaster          3.9
# 2                                Preston Marriott Hotel          4.1
# 3                          Crow Wood Hotel & Spa Resort          4.8
# 4                                           The Midland          4.5
# ...                                                 ...          ...
# ...

# %%
df['address1']
# Out:
# 0       2 Frontier Ave, Blackburn BB1 3AL, United Kingdom
# 1       Waterside Park, Caton Rd, Lancaster LA1 3RA, U...
# 2       Garstang Rd, Broughton, Preston PR3 5JB, Unite...
# 3              Holme Rd, Burnley BB12 0RT, United Kingdom
# 4          Marine Rd W, Morecambe LA4 4BU, United Kingdom
#                               ...
# 1188                                                  NaN
# 1189                                                  NaN
# 1190                                                  NaN
# 1191                                                  NaN
# 1192                                                  NaN
# Name: address1, Length: 1193, dtype: object

# %%
df['address1'] = df['address1'].str.replace(', United Kingdom','')

# %%
#df['address1'] = df['address1'].str.split(',')

# %%
df[['A', 'B']] = df['address1'].str.split(',', 1, expand=True)

# %%
df[['C', 'D']] = df['B'].str.split(',', 1, expand=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1193 entries, 0 to 1192
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     1193 non-null   int64
#  1   location       1193 non-null   object
#  2   business name  1193 non-null   object
#  3   Star Rating    1164 non-null   float64
#  4   address1       650 non-null    object
#  5   address2       2 non-null      object
#  6   Town County    3 non-null      object
#  7   Zipcode        3 non-null      object
#  8   Phone          611 non-null    object
#  9   source link    1193 non-null   object
#  10  A              650 non-null    object
#  11  B              615 non-null    object
#  12  C              615 non-null    object
#  13  D              230 non-null    object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 130.6+ KB

# %%
df['C']
# Out:
# 0        Blackburn BB1 3AL
# 1                 Caton Rd
# 2                Broughton
# 3         Burnley BB12 0RT
# 4        Morecambe LA4 4BU
#                ...
# 1188                   NaN
# 1189                   NaN
# 1190                   NaN
# 1191                   NaN
# 1192                   NaN
# Name: C, Length: 1193, dtype: object

# %%
df['D'] = df['D'].fillna(df['C'])

# %%
df.loc[df['D'] == df['C'], "C"] = " "

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1193 entries, 0 to 1192
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     1193 non-null   int64
#  1   location       1193 non-null   object
#  2   business name  1193 non-null   object
#  3   Star Rating    1164 non-null   float64
#  4   address1       650 non-null    object
#  5   address2       2 non-null      object
#  6   Town County    3 non-null      object
#  7   Zipcode        3 non-null      object
#  8   Phone          611 non-null    object
#  9   source link    1193 non-null   object
#  10  A              650 non-null    object
#  11  B              615 non-null    object
#  12  C              615 non-null    object
#  13  D              615 non-null    object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 130.6+ KB

# %%
df.head(10)
# Out:
#    Unnamed: 0    location                              business name  \
# 0           0  Lancashire                Hampton by Hilton Blackburn
# 1           1  Lancashire                      Holiday Inn Lancaster
# 2           2  Lancashire                     Preston Marriott Hotel
# 3           3  Lancashire               Crow Wood Hotel & Spa Resort
# 4           4  Lancashire                                The Midland
# 5           5  Lancashire  Mercure Blackburn Dunkenhalgh Hotel & Spa
# 6           6  Lancashire                Hampton by Hilton Blackburn
# 7           7  Lancashire                   Hotel ibis Preston North
# 8           8  Lancashire                      Holiday Inn Lancaster
# 9           9  Lancashire              Macdonald Tickled Trout Hotel
#
#    Star Rating                                           address1   address2  \
# 0          4.7                  2 Frontier Ave, Blackburn BB1 3AL        NaN
# ...

# %%
df[['Phone','address1','A','C','D']].head(20)
# Out:
#                Phone                                           address1  \
# 0    +44 1254 946060                  2 Frontier Ave, Blackburn BB1 3AL
# 1   +44 333 320 9332        Waterside Park, Caton Rd, Lancaster LA1 3RA
# 2    +44 1772 864087            Garstang Rd, Broughton, Preston PR3 5JB
# 3    +44 1282 227722                         Holme Rd, Burnley BB12 0RT
# 4   +44 333 220 3109                     Marine Rd W, Morecambe LA4 4BU
# 5    +44 1254 303400  Blackburn Rd, Clayton-le-Moors, Blackburn, Acc...
# 6    +44 1254 946060                  2 Frontier Ave, Blackburn BB1 3AL
# 7    +44 1772 957120          Ibis, North, Garstang Rd, Preston PR3 5JE
# 8   +44 333 320 9332        Waterside Park, Caton Rd, Lancaster LA1 3RA
# 9   +44 344 879 9053        Preston New Rd, Samlesbury, Preston PR5 0UJ
# 10   +44 1772 567000                       The Ringway, Preston PR1 3AU
# 11   +44 1772 862551       746-768 Garstang Rd, Barton, Preston PR3 5AA
# ...

# %%
df[['E', 'F']] = df['D'].str.split(',', 1, expand=True)

# %%
df['F'] = df['F'].fillna(df['E'])

# %%
df.loc[df['E'] == df['F'], "E"] = " "

# %%
df[['G', 'H']] = df['F'].str.split(',', 1, expand=True)
df['H'] = df['H'].fillna(df['G']) 
df.loc[df['G'] == df['H'], "G"] = " "

# %%
#df['H'].replace("''", ',', inplace=True)

# %%
df['H'][2][2]
# Out:
# 'r'

# %%
df[['H1', 'H2']] = df['H'].str.split(" ",1, expand=True)

# %%
df[['address1','A','C','E','G','H1', 'H2']].head(20)
# Out:
#                                              address1                    A  \
# 0                   2 Frontier Ave, Blackburn BB1 3AL       2 Frontier Ave
# 1         Waterside Park, Caton Rd, Lancaster LA1 3RA       Waterside Park
# 2             Garstang Rd, Broughton, Preston PR3 5JB          Garstang Rd
# 3                          Holme Rd, Burnley BB12 0RT             Holme Rd
# 4                      Marine Rd W, Morecambe LA4 4BU          Marine Rd W
# 5   Blackburn Rd, Clayton-le-Moors, Blackburn, Acc...         Blackburn Rd
# 6                   2 Frontier Ave, Blackburn BB1 3AL       2 Frontier Ave
# 7           Ibis, North, Garstang Rd, Preston PR3 5JE                 Ibis
# 8         Waterside Park, Caton Rd, Lancaster LA1 3RA       Waterside Park
# 9         Preston New Rd, Samlesbury, Preston PR5 0UJ       Preston New Rd
# 10                       The Ringway, Preston PR1 3AU          The Ringway
# ...

# %%
df['zipcode try'] = df['H2'].str[-8:]

# %%
df['H2']
# Out:
# 0       Blackburn BB1 3AL
# 1       Lancaster LA1 3RA
# 2         Preston PR3 5JB
# 3        Burnley BB12 0RT
# 4       Morecambe LA4 4BU
#               ...
# 1188                  NaN
# 1189                  NaN
# 1190                  NaN
# 1191                  NaN
# 1192                  NaN
# Name: H2, Length: 1193, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1193 entries, 0 to 1192
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     1193 non-null   int64
#  1   location       1193 non-null   object
#  2   business name  1193 non-null   object
#  3   Star Rating    1164 non-null   float64
#  4   address1       650 non-null    object
#  5   address2       2 non-null      object
#  6   Town County    3 non-null      object
#  7   Zipcode        3 non-null      object
#  8   Phone          611 non-null    object
#  9   source link    1193 non-null   object
#  10  A              650 non-null    object
#  11  B              615 non-null    object
#  12  C              615 non-null    object
#  13  D              615 non-null    object
#  14  E              615 non-null    object
#  15  F              615 non-null    object
#  16  G              615 non-null    object
# ...

# %%
df['city'] = df['H2'].str[:-8]

# %%
df['city']
# Out:
# 0       Blackburn
# 1       Lancaster
# 2         Preston
# 3        Burnley
# 4       Morecambe
#           ...
# 1188          NaN
# 1189          NaN
# 1190          NaN
# 1191          NaN
# 1192          NaN
# Name: city, Length: 1193, dtype: object

# %%
with pd.ExcelWriter('hotel_play.xlsx') as writer:
    df.to_excel(writer, sheet_name='Sheet1')
